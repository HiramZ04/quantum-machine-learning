# %% [markdown]
# #Cirq Practices#

# %%
import cirq

q0, q1, q2, q3 = cirq.LineQubit.range(4)

ops = [cirq.ry(q0), 
cirq.CNOT(q0,q1), 
cirq.ry(q1),
cirq.CNOT(q1,q2),
cirq.ry(q2),
cirq.CNOT(q2,q3),
cirq.ry(q3),

]

circuit = cirq.Circuit(ops)
print(circuit)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 5
#       1 import cirq
#       3 q0, q1, q2, q3 = cirq.LineQubit.range(4)
# ----> 5 ops = [cirq.ry(q0),
#       6 cirq.CNOT(q0,q1),
#       7 cirq.ry(q1),
#       8 cirq.CNOT(q1,q2),
#       9 cirq.ry(q2),
#      10 cirq.CNOT(q2,q3),
#      11 cirq.ry(q3),
#      12
#      13 ]
#      15 circuit = cirq.Circuit(ops)
#      16 print(circuit)
#
# File c:\Users\Hiram\AppData\Local\Programs\Python\Python312\Lib\site-packages\cirq\ops\common_gates.py:1385, in ry(rads)
#    1383 def ry(rads: value.TParamVal) -> Ry:
#    1384     """Returns a gate with the matrix $e^{-i Y t / 2}$ where $t=rads$."""
# -> 1385     return Ry(rads=rads)
#
# File c:\Users\Hiram\AppData\Local\Programs\Python\Python312\Lib\site-packages\cirq\ops\common_gates.py:530, in Ry.__init__(self, rads)
#     524 """Initialize an Ry (`cirq.YPowGate`).
# ...
